# %%
# factor plot isn~t availible so we use this
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
a = sns.load_dataset('tips')
sns.catplot(x = 'tip', y = 'size', data= a, hue = 'sex', kind = 'point')
plt.show()
