# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
a = sns.load_dataset('penguins').head(20)
sns.displot(a['bill_length_mm'], kde = True, rug = True, color='r', log_scale= True )
# rug =True for small lines

plt.show()
