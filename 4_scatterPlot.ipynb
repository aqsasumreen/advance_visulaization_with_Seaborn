# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
a = sns.load_dataset('penguins').head(20)
sns.scatterplot(x='bill_length_mm', y='flipper_length_mm', data= a, hue= 'sex', style= 'sex', sizes = (200, 150), palette= 'gist_ncar'  )
plt.show()
