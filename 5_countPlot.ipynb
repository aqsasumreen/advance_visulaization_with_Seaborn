# %%
# count of how many males and females visited the resturant
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
a = sns.load_dataset('penguins')
sns.countplot(x = 'sex', data= a, hue='island' , palette= 'inferno', saturation= 6)
# saturation = 0-100
plt.show()
