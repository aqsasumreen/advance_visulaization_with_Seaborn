# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
a = sns.load_dataset('tips')
sns.boxplot(x = 'day', y='total_bill', data=a, hue='time', showmeans = True)
plt.show()

# %%
sns.boxplot(x = 'total_bill', data=a )
plt.show()
