# %%
# multiple plots of one dataframe
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
a = sns.load_dataset('tips')
fg = sns.FacetGrid(a, col='day', hue= 'sex')
fg.map(plt.scatter, 'total_bill', 'tip').add_legend()
plt.show()
