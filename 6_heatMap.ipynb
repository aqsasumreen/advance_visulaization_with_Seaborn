# %%
# it works on 2D data
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# 1-10 me 20 data chihy with 4 rows and 5 columns
a = np.linspace(1, 10, 20).reshape(4,5)
# we can chg the minimum and maximum values
# vmin=5, vmax = 15,
# to show values
sns.heatmap(a ,  cmap = 'autumn', annot=True)
plt.show()

# %%
a1 = sns.load_dataset('anagrams').head(20)
a1
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
x = a1.drop(columns=['attnr'])
x
# Out:
#     subidr  num1  num2  num3
# 0        1     2   4.0     7
# 1        2     3   4.0     5
# 2        3     3   5.0     6
# 3        4     5   7.0     5
# 4        5     4   5.0     8
# 5        6     5   5.0     6
# 6        7     5   4.5     6
# 7        8     5   7.0     8
# 8        9     2   3.0     7
# 9       10     6   5.0     6
# 10      11     6   5.0     6
# 11      12     8   9.0     8
# 12      13     6   5.0     9
# 13      14     8   8.0     7
# 14      15     8   8.0     7
# 15      16     6   8.0     7
# 16      17     7   7.0     6
# 17      18     7   8.0     6
# 18      19     5   6.0     6
# 19      20     6   6.0     5

# %%
y = {'fontsize' : '10', 'color' : 'red'}
sns.heatmap(x, annot = True, cmap = 'ocean', annot_kws=y, linecolor='red', linewidth= 3)
plt.show()
